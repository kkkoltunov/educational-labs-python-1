# %%
import sympy
from sympy import Eq, S, Matrix, symbols, Symbol, simplify, expand, collect, solve, solveset, zeros, ones, sqrt
from sympy import pi as Pi
from sympy import cos as Cos
from sympy import sin as Sin
from sympy.plotting.plot import plot3d
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Занятие 17
# # Алгебра
# ## Поверхности второго порядка
# ### Задание 1.
# Составить в матричном виде двумя способами уравнение поверхности второго порядка $4x^2-24xy+8\sqrt3 xz-7y^2+10\sqrt3 yz+3z^2-4 = 0$. Привести уравнение поверхности второго порядка к каноническому виду с помощью перехода к новому базису. Вывести на экран каноническое уравнение.

# %%
x, y, z = symbols('x y z')
A = Matrix(((4, -12, 4*sqrt(3)), (-12, -7, 5*sqrt(3)), (4*sqrt(3), 5*sqrt(3), 3)))
b = Matrix((0, 0, 0)).T

X = Matrix((x, y, z))
display(A, Eq(simplify(expand(X.T*A*X))[0] - 4, 0))

A1 = A.row_join(b.T).col_join(b.row_join(Matrix((c,))))
display(A1)
X1 = X.col_join(Matrix((1,)))
display(Eq(simplify(expand(X1.T*A1*X1))[0], 0))

X1 = Matrix((x, y, z))
P = Matrix([])
for item in A.eigenvects():
  degree = item[1]
  for i in range(degree):
    P = P.row_join(item[2][i].normalized())

A1_new = P.T*A*P
x1, y1, z1 = symbols('x1 y1 z1')
X1_new = Matrix((x1, y1, z1))
q_f_new = simplify(expand(X1_new.T*A1_new*X1_new))[0] - 4
display(A1_new, q_f_new)
# Out:
# Matrix([
# [        4,       -12, 4*sqrt(3)],
# [      -12,        -7, 5*sqrt(3)],
# [4*sqrt(3), 5*sqrt(3),         3]])
# Eq(4*x**2 - 24*x*y + 8*sqrt(3)*x*z - 7*y**2 + 10*sqrt(3)*y*z + 3*z**2 - 4, 0)
# Matrix([
# [        4,       -12, 4*sqrt(3),   0],
# [      -12,        -7, 5*sqrt(3),   0],
# [4*sqrt(3), 5*sqrt(3),         3,   0],
# [        0,         0,         0, -12]])
# Eq(4*x**2 - 24*x*y + 8*sqrt(3)*x*z - 7*y**2 + 10*sqrt(3)*y*z + 3*z**2 - 12, 0)
# Matrix([
# [-20, 0,  0],
# [  0, 8,  0],
# [  0, 0, 12]])
# -20*x1**2 + 8*y1**2 + 12*z1**2 - 4

# %% [markdown]
# ### Задание 2.
# Привести уравнение поверхности второго порядка $24 x^{2} - 4 \sqrt{2} x y - 4 \sqrt{2} x z + 18 y^{2} + 12 y z + 18 z^{2} - 4 = 0$ к каноническому виду. Построить график.

# %%
x, y, z = symbols('x y z')
A4 = Matrix(((24, -2*sqrt(2), -2*sqrt(2)), (-2*sqrt(2), 18, 6), (-2*sqrt(2), 6, 18)))
b = Matrix((0, 0, 0))

X4 = Matrix((x, y, z))
P = Matrix([])
for item in A4.eigenvects():
  degree = item[1]
  for i in range(degree):
    P = P.row_join(item[2][i].normalized())

A4_new = P.T*A4*P
x1, y1, z1 = symbols('x1 y1 z1')
X4_new = Matrix((x1, y1, z1))
q_f_new = simplify(expand(X4_new.T*A4_new*X4_new))[0]
display(A4_new, q_f_new)

b_new = P.T*b
display(b_new)
u_new = q_f_new + 2*(b_new.T*X4_new)[0]
display(u_new)

c_new = -4
for i in range(3):
  c_new -= b_new[i]**2/(A4_new[i, i])
display(c_new) 

b_last = zeros(3, 1)
x2, y2, z2 = symbols('x2 y2 z2')
X4_last = Matrix((x2, y2, z2))
eq4 = Eq((X4_last.T*A4_new*X4_last)[0] + 2*(b_last.T*X4_last)[0] + c_new, 0)
display(eq4)

X = solve(eq4, x2)
display(*X)
plot3d(*X, (y2, -2, 2), (z2, -3, 3))
# Out:
# Matrix([
# [12,  0,  0],
# [ 0, 20,  0],
# [ 0,  0, 28]])
# 12*x1**2 + 20*y1**2 + 28*z1**2
# Matrix([
# [0],
# [0],
# [0]])
# 12*x1**2 + 20*y1**2 + 28*z1**2
# -4
# Eq(12*x2**2 + 20*y2**2 + 28*z2**2 - 4, 0)
# -sqrt(-15*y2**2 - 21*z2**2 + 3)/3
# sqrt(-15*y2**2 - 21*z2**2 + 3)/3

# %% [markdown]
# ### Задание 3.
# Привести уравнение поверхности второго порядка $x^2 + y^2 + 2x - 4y + 2z + 1 = 0$ к каноническому виду. Построить график.

# %%
z4, z3 = symbols('z4 z3')
A3 = Matrix(((1, 0, 0), (0, 1, 0), (0, 0, 0)))
b = Matrix((0, 0, 0))

x1, y1, z1 = symbols('x1 y1 z1')
X3_new = Matrix((x1, y1, z1))
q_f2 = simplify(expand(X3_new.T*A3*X3_new))[0]
display(A3, q_f2)

eq2 = Eq(q_f2, z)
display(eq2.subs(z4, z1))
Z = solve(eq2, z)
plot3d(*Z, (x1, -1, 1), (y1, -1, 1))
# Out:
# Matrix([
# [1, 0, 0],
# [0, 1, 0],
# [0, 0, 0]])
# x1**2 + y1**2
# Eq(x1**2 + y1**2, z)

# %% [markdown]
# ### Индивидуальное задание.
# Привести уравнение поверхности второго порядка к каноническому виду. Построить график.
#
# u = $25x^2 + 10\sqrt{3}xy + 35y^2 + 52z^2$

# %%
x, y, z = symbols('x y z')
A4 = Matrix(((25, 5*sqrt(3), 0), (5*sqrt(3), 35, 0), (0, 0, 52)))
display(A4)
b = Matrix((0, 0, 0))

X4 = Matrix((x, y, z))
P = Matrix([])
for item in A4.eigenvects():
  degree = item[1]
  for i in range(degree):
    P = P.row_join(item[2][i].normalized())

A4_new = P.T*A4*P
x1, y1, z1 = symbols('x1 y1 z1')
X4_new = Matrix((x1, y1, z1))
q_f_new = simplify(expand(X4_new.T*A4_new*X4_new))[0]
display(A4_new, q_f_new)

b_new = P.T*b
display(b_new)
u_new = q_f_new + 2*(b_new.T*X4_new)[0]
display(u_new)

c_new = -1
for i in range(3):
  c_new -= b_new[i]**2/(A4_new[i, i])
display(c_new) 

b_last = zeros(3, 1)
x2, y2, z2 = symbols('x2 y2 z2')
X4_last = Matrix((x2, y2, z2))
eq4 = Eq((X4_last.T*A4_new*X4_last)[0] + 2*(b_last.T*X4_last)[0] + c_new, 0)
display(eq4)

X = solve(eq4, x2)
display(*X)
plot3d(*X, (y2, -2, 2), (z2, -3, 3))
# Out:
# Matrix([
# [       25, 5*sqrt(3),  0],
# [5*sqrt(3),        35,  0],
# [        0,         0, 52]])
# Matrix([
# [20,  0,  0],
# [ 0, 40,  0],
# [ 0,  0, 52]])
# 20*x1**2 + 40*y1**2 + 52*z1**2
# Matrix([
# [0],
# [0],
# [0]])
# 20*x1**2 + 40*y1**2 + 52*z1**2
# -1
# Eq(20*x2**2 + 40*y2**2 + 52*z2**2 - 1, 0)
# -sqrt(-200*y2**2 - 260*z2**2 + 5)/10
# sqrt(-200*y2**2 - 260*z2**2 + 5)/10
